# %%
import yfinance as yf
import pandas as pd
import os
import random
import gymnasium
from gymnasium import Env
from gymnasium.spaces import Discrete,Box
import numpy as np
from gymnasium import spaces
import matplotlib.pyplot as plt
from stable_baselines3 import PPO,A2C,DDPG
from stable_baselines3.common.vec_env import DummyVecEnv
from stable_baselines3.common.noise import NormalActionNoise
import torch
import random

# %%
if not os.path.exists("nifty_data_2010_2019"):
    os.makedirs("nifty_data_2010_2019")

survivors=[
    "ACC.NS","AMBUJACEM.NS","AXISBANK.NS","BHARTIARTL.NS","BPCL.NS",
    "CIPLA.NS","GAIL.NS","GRASIM.NS","HCLTECH.NS","HDFCBANK.NS",
    "HEROMOTOCO.NS","HINDALCO.NS","HINDUNILVR.NS","ICICIBANK.NS","INFY.NS",
    "ITC.NS","LT.NS","M&M.NS","MARUTI.NS","NTPC.NS","ONGC.NS",
    "POWERGRID.NS","RELIANCE.NS","SBIN.NS","SUNPHARMA.NS","TCS.NS",
    "TATASTEEL.NS","WIPRO.NS","ABB.NS","BHEL.NS",
    "DLF.NS","IDEA.NS","JPASSOCIAT.NS","JINDALSTEL.NS",
    "PNB.NS","RELINFRA.NS","RPOWER.NS","SAIL.NS","SIEMENS.NS",
    "SUZLON.NS","TATAPOWER.NS","UNITECH.NS","RCOM.NS"
]

for ticker in survivors:
      df=yf.download(ticker,start="2010-01-01",end="2020-01-01")
      if not df.empty:
           filename=f"nifty_data_2010_2019/{ticker}.csv"
           df.to_csv(filename)
           print(f"Success:{ticker}")

# %%
path=r"D:\Data Science and ML\Reinforcement Learning\Midterm Submission\nifty_data_2010_2019"
for filename in os.listdir(path):
   filepath=os.path.join(path,filename)
   df=pd.read_csv(filepath)
   df=df.dropna()
   df.to_csv(filepath,index=False)

# %%
path=r"D:\Data Science and ML\Reinforcement Learning\Midterm Submission\nifty_data_2010_2019"

if os.path.exists(path):
    for filename in os.listdir(path):
        if filename.endswith(".csv"):
            filepath=os.path.join(path,filename)
            df=pd.read_csv(filepath)
            df=df.iloc[1:].copy()

            if 'Price' in df.columns:
                df=df.rename(columns={'Price':'Date'})

            df['Date']=pd.to_datetime(df['Date'])
            df=df.set_index('Date')

            cols=['High','Low','Close']
            for c in cols:
                df[c]=pd.to_numeric(df[c],errors='coerce')

            df=df.dropna()

            df["Daily Return"]=df["Close"].pct_change()

            # MACD
            k_fast=df["Close"].ewm(span=12,adjust=False).mean()
            k_slow=df["Close"].ewm(span=26,adjust=False).mean()
            df["MACD"]=k_fast-k_slow

            # RSI
            delta=df["Close"].diff()
            gain=delta.where(delta>0,0)
            loss=-delta.where(delta<0,0)

            avg_gain=gain.ewm(alpha=1/14,adjust=False).mean()
            avg_loss=loss.ewm(alpha=1/14,adjust=False).mean()

            rs=avg_gain/avg_loss
            df["RSI"]=100-(100/(1+rs))

            # CCI
            tp=(df['High']+df['Low']+df['Close'])/3
            sma_tp=tp.rolling(window=20).mean()

            md=(tp-sma_tp).abs().rolling(window=20).mean()
            df["CCI"]=(tp-sma_tp)/(0.015*md)

            # ADX
            prev_close=df['Close'].shift(1)
            tr1=df['High']-df['Low']
            tr2=(df['High']-prev_close).abs()
            tr3=(df['Low']-prev_close).abs()
            tr=pd.concat([tr1,tr2,tr3],axis=1).max(axis=1)

            up_move=df['High']-df['High'].shift(1)
            down_move=df['Low'].shift(1)-df['Low']

            plus_dm=np.where((up_move>down_move) & (up_move>0),up_move,0.0)
            minus_dm=np.where((down_move>up_move) & (down_move>0),down_move,0.0)

            tr_smooth=tr.ewm(alpha=1/14,adjust=False).mean()
            plus_di=100*(pd.Series(plus_dm,index=df.index).ewm(alpha=1/14,adjust=False).mean()/tr_smooth)
            minus_di=100*(pd.Series(minus_dm,index=df.index).ewm(alpha=1/14,adjust=False).mean()/tr_smooth)

            dx=100*(abs(plus_di-minus_di)/(plus_di+minus_di))
            df["ADX"]=dx.ewm(alpha=1/14,adjust=False).mean()

            df=df.dropna()

            df.to_csv(filepath,index=True)

    print("All files updated with MACD,RSI,CCI,and ADX.")
else:
    print("Folder not found.")
# Out:
# All files updated with MACD,RSI,CCI,and ADX.

# %%
f=pd.read_csv(r"D:\Data Science and ML\Reinforcement Learning\Midterm Submission\nifty_data_2010_2019\ABB.NS.csv")
f.head()
# Out:
#          Date       Close        High         Low        Open  Volume  \
# 0  2010-03-02  666.643555  685.812218  660.254038  685.812218  445384
# 1  2010-03-03  678.954285  681.424877  663.278582  668.773566  279846
# 2  2010-03-04  681.424866  685.812365  673.927806  674.737170  179884
# 3  2010-03-05  700.465759  702.766013  679.848816  682.404634  449349
# 4  2010-03-08  720.912292  723.808902  702.851112  707.110828  574636
#
#    Daily Return      MACD        RSI         CCI        ADX
# 0     -0.015228 -0.390713  41.986123  -67.446886  20.564921
# 1      0.018467 -0.518769  48.901066  -37.916279  20.179500
# 2      0.003639 -0.416103  50.184350    1.300686  19.390730
# 3      0.027943  1.188007  58.776935   83.020658  18.748102
# 4      0.029190  4.062313  65.632234  185.251961  19.386865

# %%
class StockTradingEnv(gymnasium.Env):
    def __init__(self,data,raw_data,stock_dim,initial_balance=1000000,transaction_cost_pct=0.001):
        super(StockTradingEnv,self).__init__()

        self.data=data
        self.raw_data=raw_data
        self.stock_dim=stock_dim
        self.initial_balance=initial_balance
        self.transaction_cost_pct=transaction_cost_pct
        self.h_max=1000 # Maximum shares to trade per step
        self.max_portfolio_value=initial_balance

        # Action Space
        self.action_space=spaces.Box(low=-1,high=1,shape=(self.stock_dim,),dtype=np.float32)

        # Observation Space:Balance+Holdings+Prices+Indicators
        num_features_per_stock=self.data.shape[2]
        self.obs_shape=1+self.stock_dim+(self.stock_dim*num_features_per_stock)
        self.observation_space=spaces.Box(low=-np.inf,high=np.inf,shape=(self.obs_shape,),dtype=np.float32)

        self.reset()

    def reset(self,seed=None):
        super().reset(seed=seed)
        self.day=0
        self.balance=self.initial_balance
        self.holdings=np.zeros(self.stock_dim)
        self.portfolio_value=self.initial_balance
        self.max_portfolio_value=self.initial_balance
        return self._get_observation(),{}

    def step(self,actions):

        done=self.day>=len(self.data)-1
        if done:
            return self._get_observation(),0,done,False,{}

        # Get current market prices
        current_prices=self.raw_data[self.day][:,0]

        # Interpret Actions
        delta_holdings=np.floor(actions*self.h_max).astype(int)
        transaction_cost=0

        for i in range(self.stock_dim):
            action_shares=delta_holdings[i]
            price=current_prices[i]

            # SELL
            if action_shares<0:
                # You can only sell what you currently own
                shares_to_sell=min(abs(action_shares),self.holdings[i])

                if shares_to_sell>0:
                    self.holdings[i]-=shares_to_sell
                    cash_in=shares_to_sell*price
                    cost=cash_in*self.transaction_cost_pct
                    self.balance+=(cash_in-cost)
                    transaction_cost+=cost

            # BUY
            elif action_shares>0:
                cost=action_shares*price*self.transaction_cost_pct
                total_cost=(action_shares*price)+cost

                # You can only buy if you have enough cash
                if self.balance>=total_cost:
                    self.holdings[i]+=action_shares
                    self.balance-=total_cost
                    transaction_cost+=cost

        self.day+=1
        next_prices=self.raw_data[self.day][:,0]

        # Reward=New Portfolio Value-Old Portfolio Value
        new_portfolio_value=self.balance+np.sum(next_prices*self.holdings)
        daily_return=(new_portfolio_value-self.portfolio_value)
        reward=daily_return 

        # Update for next step
        self.portfolio_value=new_portfolio_value

        return self._get_observation(),reward*5,done,False,{}

    def _get_observation(self):
        # 1. Scale Balance: Relative to initial (starts at 1.0)
        scaled_balance=self.balance/self.initial_balance

        # 2. Scale Holdings: The model should know how much it owns relative to h_max
        # Or simply provide them as is if h_max is small,but scaling helps.
        scaled_holdings=self.holdings/self.h_max

        # 3. Normalized Features (already handled by rolling_norm)
        current_features=self.data[self.day].flatten()

        return np.concatenate(([scaled_balance],scaled_holdings,current_features)).astype(np.float32)

# %%
def merge_data(directory_path):
    required_features=['Close','MACD','RSI','CCI','ADX']

    merged_data={}

    print("Reading files...")
    for filename in os.listdir(directory_path):
        if filename.endswith(".csv"):
            ticker=filename.replace(".csv","")
            filepath=os.path.join(directory_path,filename)

            df=pd.read_csv(filepath)
            df['Date']=pd.to_datetime(df['Date'])
            df=df.set_index('Date')

            try:
                df=df[required_features]
                merged_data[ticker]=df
            except KeyError as e:
                print(f"Skipping {ticker}:Missing columns {e}")

    all_dates=pd.Index([])
    for df in merged_data.values():
        all_dates=all_dates.union(df.index)

    all_dates=all_dates.sort_values()

    tickers_list=sorted(list(merged_data.keys()))
    num_stocks=len(tickers_list)
    num_features=len(required_features)
    num_timesteps=len(all_dates)

    final_array=np.zeros((num_timesteps,num_stocks,num_features))

    for i,ticker in enumerate(tickers_list):
        df=merged_data[ticker]

        df_reindexed=df.reindex(all_dates)

        df_reindexed=df_reindexed.ffill().bfill()

        final_array[:,i,:]=df_reindexed.values

    if np.isnan(final_array).any():
        final_array=np.nan_to_num(final_array)

    print(f"Final Data Shape:{final_array.shape}")
    final_array=final_array.astype(np.float32)
    return final_array,tickers_list

data_path=r"D:\Data Science and ML\Reinforcement Learning\Midterm Submission\nifty_data_2010_2019"
train_data,tickers=merge_data(data_path)
# Out:
# Reading files...
# Final Data Shape:(2425, 43, 5)

# %%
def rolling_norm(data,window=50):
  days,stocks,features=data.shape
  norm_data=np.zeros_like(data,dtype=np.float32)

  for i in range(stocks):
    for j in range(features):
      series=pd.Series(data[:,i,j])
      rolling=series.rolling(window=window,min_periods=1)
      mean=rolling.mean()
      std=rolling.std(ddof=0)
      norm_data[:,i,j]=(data[:,i,j]-mean)/(std+1e-10)

  return norm_data

# %%
normed_data=rolling_norm(train_data)
np.save(r"D:\Data Science and ML\Reinforcement Learning\Midterm Submission\normed_data",normed_data)

# %%
train_data.shape
# Out:
# (2425, 43, 5)

# %%
train_end=int(len(normed_data)*0.90)

train_norm=normed_data[:train_end]
train_raw=train_data[:train_end]


env_train=StockTradingEnv(data=train_norm,raw_data=train_raw,stock_dim=len(tickers))

print("--- Starting PPO Training ---")
model_ppo=PPO(
    "MlpPolicy",
    env_train,
    verbose=1,
    learning_rate=0.0003,
    n_steps=2048,
    n_epochs=15,
    batch_size=64,
)

model_ppo.learn(total_timesteps=100000)
print("PPO Training Complete.")
# Out:
# --- Starting PPO Training ---
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# -----------------------------
# | time/              |      |
# |    fps             | 1986 |
# |    iterations      | 1    |
# |    time_elapsed    | 1    |
# |    total_timesteps | 2048 |
# -----------------------------
# --------------------------------------------
# | rollout/                |                |
# |    ep_len_mean          | 2.18e+03       |
# |    ep_rew_mean          | -3.34e+06      |
# | time/                   |                |
# |    fps                  | 1090           |
# |    iterations           | 2              |
# |    time_elapsed         | 3              |
# |    total_timesteps      | 4096           |
# | train/                  |                |
# |    approx_kl            | 0.000111818896 |
# |    clip_fraction        | 0              |
# |    clip_range           | 0.2            |
# |    entropy_loss         | -61            |
# |    explained_variance   | -2.38e-07      |
# |    learning_rate        | 0.0003         |
# |    loss                 | 1.05e+10       |
# |    n_updates            | 15             |
# |    policy_gradient_loss | -0.00532       |
# |    std                  | 1              |
# |    value_loss           | 2.05e+10       |
# --------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 2.18e+03      |
# |    ep_rew_mean          | -1.5e+06      |
# | time/                   |               |
# |    fps                  | 969           |
# |    iterations           | 3             |
# |    time_elapsed         | 6             |
# |    total_timesteps      | 6144          |
# | train/                  |               |
# |    approx_kl            | 1.1024444e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -61           |
# |    explained_variance   | 3.81e-05      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 2.37e+10      |
# |    n_updates            | 30            |
# |    policy_gradient_loss | -0.00129      |
# |    std                  | 1             |
# |    value_loss           | 6.25e+10      |
# -------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 2.18e+03   |
# |    ep_rew_mean          | -2.14e+06  |
# | time/                   |            |
# |    fps                  | 899        |
# |    iterations           | 4          |
# |    time_elapsed         | 9          |
# |    total_timesteps      | 8192       |
# | train/                  |            |
# |    approx_kl            | 1.0894e-05 |
# |    clip_fraction        | 0          |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -61        |
# |    explained_variance   | 0.000139   |
# |    learning_rate        | 0.0003     |
# |    loss                 | 2.7e+10    |
# |    n_updates            | 45         |
# |    policy_gradient_loss | -0.00124   |
# |    std                  | 1          |
# |    value_loss           | 4.61e+10   |
# ----------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 2.18e+03      |
# |    ep_rew_mean          | -2.29e+06     |
# | time/                   |               |
# |    fps                  | 875           |
# |    iterations           | 5             |
# |    time_elapsed         | 11            |
# |    total_timesteps      | 10240         |
# | train/                  |               |
# |    approx_kl            | 2.5885965e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -61           |
# |    explained_variance   | 0.00032       |
# |    learning_rate        | 0.0003        |
# |    loss                 | 9.29e+09      |
# |    n_updates            | 60            |
# |    policy_gradient_loss | -0.00203      |
# |    std                  | 1             |
# |    value_loss           | 2e+10         |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 2.18e+03     |
# |    ep_rew_mean          | -2.42e+06    |
# | time/                   |              |
# |    fps                  | 845          |
# |    iterations           | 6            |
# |    time_elapsed         | 14           |
# |    total_timesteps      | 12288        |
# | train/                  |              |
# |    approx_kl            | 9.821524e-06 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -61          |
# |    explained_variance   | 0.000271     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.78e+10     |
# |    n_updates            | 75           |
# |    policy_gradient_loss | -0.00119     |
# |    std                  | 1            |
# |    value_loss           | 4.15e+10     |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 2.18e+03      |
# |    ep_rew_mean          | -2.67e+06     |
# | time/                   |               |
# |    fps                  | 832           |
# |    iterations           | 7             |
# |    time_elapsed         | 17            |
# |    total_timesteps      | 14336         |
# | train/                  |               |
# |    approx_kl            | 1.8877763e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -61           |
# |    explained_variance   | 0.000528      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 8.92e+09      |
# |    n_updates            | 90            |
# |    policy_gradient_loss | -0.00159      |
# |    std                  | 1             |
# |    value_loss           | 1.98e+10      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 2.18e+03      |
# |    ep_rew_mean          | -2.84e+06     |
# | time/                   |               |
# |    fps                  | 826           |
# |    iterations           | 8             |
# |    time_elapsed         | 19            |
# |    total_timesteps      | 16384         |
# | train/                  |               |
# |    approx_kl            | 2.1773041e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -61           |
# |    explained_variance   | 0.000598      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 1.21e+10      |
# |    n_updates            | 105           |
# |    policy_gradient_loss | -0.00182      |
# |    std                  | 1             |
# |    value_loss           | 1.92e+10      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 2.18e+03      |
# |    ep_rew_mean          | -2.83e+06     |
# | time/                   |               |
# |    fps                  | 826           |
# |    iterations           | 9             |
# |    time_elapsed         | 22            |
# |    total_timesteps      | 18432         |
# | train/                  |               |
# |    approx_kl            | 1.5949452e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -61           |
# |    explained_variance   | 0.000726      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 7.07e+09      |
# |    n_updates            | 120           |
# |    policy_gradient_loss | -0.00155      |
# |    std                  | 1             |
# |    value_loss           | 1.86e+10      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 2.18e+03      |
# |    ep_rew_mean          | -2.93e+06     |
# | time/                   |               |
# |    fps                  | 823           |
# |    iterations           | 10            |
# |    time_elapsed         | 24            |
# |    total_timesteps      | 20480         |
# | train/                  |               |
# |    approx_kl            | 1.4567748e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -61           |
# |    explained_variance   | 0.000704      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 1.71e+10      |
# |    n_updates            | 135           |
# |    policy_gradient_loss | -0.00139      |
# |    std                  | 1             |
# |    value_loss           | 2.33e+10      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 2.18e+03      |
# |    ep_rew_mean          | -2.86e+06     |
# | time/                   |               |
# |    fps                  | 824           |
# |    iterations           | 11            |
# |    time_elapsed         | 27            |
# |    total_timesteps      | 22528         |
# | train/                  |               |
# |    approx_kl            | 1.2524921e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -61           |
# |    explained_variance   | 0.000767      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 1.03e+10      |
# |    n_updates            | 150           |
# |    policy_gradient_loss | -0.00136      |
# |    std                  | 1             |
# |    value_loss           | 2.52e+10      |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 2.18e+03     |
# |    ep_rew_mean          | -2.88e+06    |
# | time/                   |              |
# |    fps                  | 823          |
# |    iterations           | 12           |
# |    time_elapsed         | 29           |
# |    total_timesteps      | 24576        |
# | train/                  |              |
# |    approx_kl            | 6.825634e-06 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -61          |
# |    explained_variance   | 0.000657     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.12e+10     |
# |    n_updates            | 165          |
# |    policy_gradient_loss | -0.000939    |
# |    std                  | 1            |
# |    value_loss           | 3.34e+10     |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 2.18e+03      |
# |    ep_rew_mean          | -2.89e+06     |
# | time/                   |               |
# |    fps                  | 823           |
# |    iterations           | 13            |
# |    time_elapsed         | 32            |
# |    total_timesteps      | 26624         |
# | train/                  |               |
# |    approx_kl            | 6.8669033e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -61           |
# |    explained_variance   | 0.000755      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 2e+10         |
# |    n_updates            | 180           |
# |    policy_gradient_loss | -0.000906     |
# |    std                  | 1             |
# |    value_loss           | 3.98e+10      |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 2.18e+03     |
# |    ep_rew_mean          | -2.87e+06    |
# | time/                   |              |
# |    fps                  | 822          |
# |    iterations           | 14           |
# |    time_elapsed         | 34           |
# |    total_timesteps      | 28672        |
# | train/                  |              |
# |    approx_kl            | 7.943105e-06 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -61          |
# |    explained_variance   | 0.000868     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.1e+10      |
# |    n_updates            | 195          |
# |    policy_gradient_loss | -0.001       |
# |    std                  | 1            |
# |    value_loss           | 2.97e+10     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 2.18e+03     |
# |    ep_rew_mean          | -2.77e+06    |
# | time/                   |              |
# |    fps                  | 823          |
# |    iterations           | 15           |
# |    time_elapsed         | 37           |
# |    total_timesteps      | 30720        |
# | train/                  |              |
# |    approx_kl            | 8.009432e-06 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -61          |
# |    explained_variance   | 0.000905     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.36e+10     |
# |    n_updates            | 210          |
# |    policy_gradient_loss | -0.00102     |
# |    std                  | 1            |
# |    value_loss           | 3.59e+10     |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 2.18e+03      |
# |    ep_rew_mean          | -2.7e+06      |
# | time/                   |               |
# |    fps                  | 823           |
# |    iterations           | 16            |
# |    time_elapsed         | 39            |
# |    total_timesteps      | 32768         |
# | train/                  |               |
# |    approx_kl            | 4.2979373e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -61           |
# |    explained_variance   | 0.000807      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 2.03e+10      |
# |    n_updates            | 225           |
# |    policy_gradient_loss | -0.000631     |
# |    std                  | 1             |
# |    value_loss           | 4.81e+10      |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 2.18e+03     |
# |    ep_rew_mean          | -2.7e+06     |
# | time/                   |              |
# |    fps                  | 822          |
# |    iterations           | 17           |
# |    time_elapsed         | 42           |
# |    total_timesteps      | 34816        |
# | train/                  |              |
# |    approx_kl            | 5.172449e-06 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -61          |
# |    explained_variance   | 0.000969     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.33e+10     |
# |    n_updates            | 240          |
# |    policy_gradient_loss | -0.000794    |
# |    std                  | 1            |
# |    value_loss           | 3.49e+10     |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 2.18e+03      |
# |    ep_rew_mean          | -2.79e+06     |
# | time/                   |               |
# |    fps                  | 820           |
# |    iterations           | 18            |
# |    time_elapsed         | 44            |
# |    total_timesteps      | 36864         |
# | train/                  |               |
# |    approx_kl            | 1.0637625e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -61           |
# |    explained_variance   | 0.00157       |
# |    learning_rate        | 0.0003        |
# |    loss                 | 7.29e+09      |
# |    n_updates            | 255           |
# |    policy_gradient_loss | -0.00116      |
# |    std                  | 1             |
# |    value_loss           | 1.59e+10      |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 2.18e+03     |
# |    ep_rew_mean          | -2.76e+06    |
# | time/                   |              |
# |    fps                  | 820          |
# |    iterations           | 19           |
# |    time_elapsed         | 47           |
# |    total_timesteps      | 38912        |
# | train/                  |              |
# |    approx_kl            | 7.074239e-06 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -61          |
# |    explained_variance   | 0.00118      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.44e+10     |
# |    n_updates            | 270          |
# |    policy_gradient_loss | -0.000926    |
# |    std                  | 1            |
# |    value_loss           | 2.89e+10     |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 2.18e+03      |
# |    ep_rew_mean          | -2.71e+06     |
# | time/                   |               |
# |    fps                  | 819           |
# |    iterations           | 20            |
# |    time_elapsed         | 49            |
# |    total_timesteps      | 40960         |
# | train/                  |               |
# |    approx_kl            | 4.6383357e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -61           |
# |    explained_variance   | 0.00112       |
# |    learning_rate        | 0.0003        |
# |    loss                 | 2.21e+10      |
# |    n_updates            | 285           |
# |    policy_gradient_loss | -0.000752     |
# |    std                  | 1             |
# |    value_loss           | 4.07e+10      |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 2.18e+03     |
# |    ep_rew_mean          | -2.75e+06    |
# | time/                   |              |
# |    fps                  | 819          |
# |    iterations           | 21           |
# |    time_elapsed         | 52           |
# |    total_timesteps      | 43008        |
# | train/                  |              |
# |    approx_kl            | 4.919799e-06 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -61          |
# |    explained_variance   | 0.00107      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.4e+10      |
# |    n_updates            | 300          |
# |    policy_gradient_loss | -0.000738    |
# |    std                  | 1            |
# |    value_loss           | 4.19e+10     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 2.18e+03     |
# |    ep_rew_mean          | -2.72e+06    |
# | time/                   |              |
# |    fps                  | 818          |
# |    iterations           | 22           |
# |    time_elapsed         | 55           |
# |    total_timesteps      | 45056        |
# | train/                  |              |
# |    approx_kl            | 4.864094e-06 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -61          |
# |    explained_variance   | 0.00134      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.98e+10     |
# |    n_updates            | 315          |
# |    policy_gradient_loss | -0.000714    |
# |    std                  | 1            |
# |    value_loss           | 3.39e+10     |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 2.18e+03      |
# |    ep_rew_mean          | -2.77e+06     |
# | time/                   |               |
# |    fps                  | 818           |
# |    iterations           | 23            |
# |    time_elapsed         | 57            |
# |    total_timesteps      | 47104         |
# | train/                  |               |
# |    approx_kl            | 7.4354466e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -61           |
# |    explained_variance   | 0.00165       |
# |    learning_rate        | 0.0003        |
# |    loss                 | 8.96e+09      |
# |    n_updates            | 330           |
# |    policy_gradient_loss | -0.000899     |
# |    std                  | 1             |
# |    value_loss           | 2.4e+10       |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 2.18e+03      |
# |    ep_rew_mean          | -2.74e+06     |
# | time/                   |               |
# |    fps                  | 817           |
# |    iterations           | 24            |
# |    time_elapsed         | 60            |
# |    total_timesteps      | 49152         |
# | train/                  |               |
# |    approx_kl            | 4.7694775e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -61           |
# |    explained_variance   | 0.00159       |
# |    learning_rate        | 0.0003        |
# |    loss                 | 1.47e+10      |
# |    n_updates            | 345           |
# |    policy_gradient_loss | -0.000718     |
# |    std                  | 1             |
# |    value_loss           | 2.55e+10      |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 2.18e+03     |
# |    ep_rew_mean          | -2.72e+06    |
# | time/                   |              |
# |    fps                  | 817          |
# |    iterations           | 25           |
# |    time_elapsed         | 62           |
# |    total_timesteps      | 51200        |
# | train/                  |              |
# |    approx_kl            | 4.867121e-06 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -61          |
# |    explained_variance   | 0.00159      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.16e+10     |
# |    n_updates            | 360          |
# |    policy_gradient_loss | -0.000703    |
# |    std                  | 1            |
# |    value_loss           | 2.98e+10     |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 2.18e+03      |
# |    ep_rew_mean          | -2.74e+06     |
# | time/                   |               |
# |    fps                  | 817           |
# |    iterations           | 26            |
# |    time_elapsed         | 65            |
# |    total_timesteps      | 53248         |
# | train/                  |               |
# |    approx_kl            | 4.4180197e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -61           |
# |    explained_variance   | 0.00165       |
# |    learning_rate        | 0.0003        |
# |    loss                 | 1.78e+10      |
# |    n_updates            | 375           |
# |    policy_gradient_loss | -0.000607     |
# |    std                  | 1             |
# |    value_loss           | 2.99e+10      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 2.18e+03      |
# |    ep_rew_mean          | -2.76e+06     |
# | time/                   |               |
# |    fps                  | 816           |
# |    iterations           | 27            |
# |    time_elapsed         | 67            |
# |    total_timesteps      | 55296         |
# | train/                  |               |
# |    approx_kl            | 6.4115447e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -61           |
# |    explained_variance   | 0.00188       |
# |    learning_rate        | 0.0003        |
# |    loss                 | 1.47e+10      |
# |    n_updates            | 390           |
# |    policy_gradient_loss | -0.000758     |
# |    std                  | 1             |
# |    value_loss           | 2.44e+10      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 2.18e+03      |
# |    ep_rew_mean          | -2.75e+06     |
# | time/                   |               |
# |    fps                  | 817           |
# |    iterations           | 28            |
# |    time_elapsed         | 70            |
# |    total_timesteps      | 57344         |
# | train/                  |               |
# |    approx_kl            | 6.6469656e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -61           |
# |    explained_variance   | 0.00188       |
# |    learning_rate        | 0.0003        |
# |    loss                 | 1.27e+10      |
# |    n_updates            | 405           |
# |    policy_gradient_loss | -0.000791     |
# |    std                  | 1             |
# |    value_loss           | 2.72e+10      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 2.18e+03      |
# |    ep_rew_mean          | -2.67e+06     |
# | time/                   |               |
# |    fps                  | 816           |
# |    iterations           | 29            |
# |    time_elapsed         | 72            |
# |    total_timesteps      | 59392         |
# | train/                  |               |
# |    approx_kl            | 4.5915367e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -61           |
# |    explained_variance   | 0.00191       |
# |    learning_rate        | 0.0003        |
# |    loss                 | 1.17e+10      |
# |    n_updates            | 420           |
# |    policy_gradient_loss | -0.000711     |
# |    std                  | 1             |
# |    value_loss           | 2.87e+10      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 2.18e+03      |
# |    ep_rew_mean          | -2.68e+06     |
# | time/                   |               |
# |    fps                  | 817           |
# |    iterations           | 30            |
# |    time_elapsed         | 75            |
# |    total_timesteps      | 61440         |
# | train/                  |               |
# |    approx_kl            | 2.7219066e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -61           |
# |    explained_variance   | 0.00134       |
# |    learning_rate        | 0.0003        |
# |    loss                 | 1.73e+10      |
# |    n_updates            | 435           |
# |    policy_gradient_loss | -0.000554     |
# |    std                  | 1             |
# |    value_loss           | 5.61e+10      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 2.18e+03      |
# |    ep_rew_mean          | -2.71e+06     |
# | time/                   |               |
# |    fps                  | 816           |
# |    iterations           | 31            |
# |    time_elapsed         | 77            |
# |    total_timesteps      | 63488         |
# | train/                  |               |
# |    approx_kl            | 4.1793974e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -61           |
# |    explained_variance   | 0.00187       |
# |    learning_rate        | 0.0003        |
# |    loss                 | 2.01e+10      |
# |    n_updates            | 450           |
# |    policy_gradient_loss | -0.000646     |
# |    std                  | 1             |
# |    value_loss           | 3.2e+10       |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 2.18e+03     |
# |    ep_rew_mean          | -2.64e+06    |
# | time/                   |              |
# |    fps                  | 816          |
# |    iterations           | 32           |
# |    time_elapsed         | 80           |
# |    total_timesteps      | 65536        |
# | train/                  |              |
# |    approx_kl            | 6.536371e-06 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -61          |
# |    explained_variance   | 0.00248      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.11e+10     |
# |    n_updates            | 465          |
# |    policy_gradient_loss | -0.000851    |
# |    std                  | 1            |
# |    value_loss           | 1.87e+10     |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 2.18e+03      |
# |    ep_rew_mean          | -2.64e+06     |
# | time/                   |               |
# |    fps                  | 815           |
# |    iterations           | 33            |
# |    time_elapsed         | 82            |
# |    total_timesteps      | 67584         |
# | train/                  |               |
# |    approx_kl            | 1.6733538e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -61           |
# |    explained_variance   | 0.00117       |
# |    learning_rate        | 0.0003        |
# |    loss                 | 2.88e+10      |
# |    n_updates            | 480           |
# |    policy_gradient_loss | -0.000398     |
# |    std                  | 1             |
# |    value_loss           | 8.12e+10      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 2.18e+03      |
# |    ep_rew_mean          | -2.65e+06     |
# | time/                   |               |
# |    fps                  | 815           |
# |    iterations           | 34            |
# |    time_elapsed         | 85            |
# |    total_timesteps      | 69632         |
# | train/                  |               |
# |    approx_kl            | 6.6266803e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -61           |
# |    explained_variance   | 0.00224       |
# |    learning_rate        | 0.0003        |
# |    loss                 | 6.33e+09      |
# |    n_updates            | 495           |
# |    policy_gradient_loss | -0.000792     |
# |    std                  | 1             |
# |    value_loss           | 2.57e+10      |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 2.18e+03     |
# |    ep_rew_mean          | -2.68e+06    |
# | time/                   |              |
# |    fps                  | 814          |
# |    iterations           | 35           |
# |    time_elapsed         | 87           |
# |    total_timesteps      | 71680        |
# | train/                  |              |
# |    approx_kl            | 4.235102e-06 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -61          |
# |    explained_variance   | 0.00255      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.08e+10     |
# |    n_updates            | 510          |
# |    policy_gradient_loss | -0.000658    |
# |    std                  | 1            |
# |    value_loss           | 2.33e+10     |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 2.18e+03      |
# |    ep_rew_mean          | -2.69e+06     |
# | time/                   |               |
# |    fps                  | 814           |
# |    iterations           | 36            |
# |    time_elapsed         | 90            |
# |    total_timesteps      | 73728         |
# | train/                  |               |
# |    approx_kl            | 5.3650583e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -61           |
# |    explained_variance   | 0.00279       |
# |    learning_rate        | 0.0003        |
# |    loss                 | 1.26e+10      |
# |    n_updates            | 525           |
# |    policy_gradient_loss | -0.000707     |
# |    std                  | 1             |
# |    value_loss           | 1.99e+10      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 2.18e+03      |
# |    ep_rew_mean          | -2.72e+06     |
# | time/                   |               |
# |    fps                  | 813           |
# |    iterations           | 37            |
# |    time_elapsed         | 93            |
# |    total_timesteps      | 75776         |
# | train/                  |               |
# |    approx_kl            | 4.5322813e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -61           |
# |    explained_variance   | 0.00269       |
# |    learning_rate        | 0.0003        |
# |    loss                 | 1.02e+10      |
# |    n_updates            | 540           |
# |    policy_gradient_loss | -0.000661     |
# |    std                  | 1             |
# |    value_loss           | 2.1e+10       |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 2.18e+03      |
# |    ep_rew_mean          | -2.73e+06     |
# | time/                   |               |
# |    fps                  | 813           |
# |    iterations           | 38            |
# |    time_elapsed         | 95            |
# |    total_timesteps      | 77824         |
# | train/                  |               |
# |    approx_kl            | 5.4444536e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -61           |
# |    explained_variance   | 0.0025        |
# |    learning_rate        | 0.0003        |
# |    loss                 | 1.95e+10      |
# |    n_updates            | 555           |
# |    policy_gradient_loss | -0.000695     |
# |    std                  | 1             |
# |    value_loss           | 2.73e+10      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 2.18e+03      |
# |    ep_rew_mean          | -2.76e+06     |
# | time/                   |               |
# |    fps                  | 812           |
# |    iterations           | 39            |
# |    time_elapsed         | 98            |
# |    total_timesteps      | 79872         |
# | train/                  |               |
# |    approx_kl            | 5.3527183e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -61           |
# |    explained_variance   | 0.00281       |
# |    learning_rate        | 0.0003        |
# |    loss                 | 1.43e+10      |
# |    n_updates            | 570           |
# |    policy_gradient_loss | -0.000689     |
# |    std                  | 1             |
# |    value_loss           | 2.41e+10      |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 2.18e+03     |
# |    ep_rew_mean          | -2.78e+06    |
# | time/                   |              |
# |    fps                  | 812          |
# |    iterations           | 40           |
# |    time_elapsed         | 100          |
# |    total_timesteps      | 81920        |
# | train/                  |              |
# |    approx_kl            | 9.555399e-06 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -61          |
# |    explained_variance   | 0.00304      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.08e+10     |
# |    n_updates            | 585          |
# |    policy_gradient_loss | -0.000949    |
# |    std                  | 1            |
# |    value_loss           | 2.11e+10     |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 2.18e+03      |
# |    ep_rew_mean          | -2.75e+06     |
# | time/                   |               |
# |    fps                  | 812           |
# |    iterations           | 41            |
# |    time_elapsed         | 103           |
# |    total_timesteps      | 83968         |
# | train/                  |               |
# |    approx_kl            | 6.5084896e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -61           |
# |    explained_variance   | 0.00216       |
# |    learning_rate        | 0.0003        |
# |    loss                 | 2.31e+10      |
# |    n_updates            | 600           |
# |    policy_gradient_loss | -0.000839     |
# |    std                  | 1             |
# |    value_loss           | 3.68e+10      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 2.18e+03      |
# |    ep_rew_mean          | -2.75e+06     |
# | time/                   |               |
# |    fps                  | 811           |
# |    iterations           | 42            |
# |    time_elapsed         | 105           |
# |    total_timesteps      | 86016         |
# | train/                  |               |
# |    approx_kl            | 2.9586372e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -61           |
# |    explained_variance   | 0.00232       |
# |    learning_rate        | 0.0003        |
# |    loss                 | 1.38e+10      |
# |    n_updates            | 615           |
# |    policy_gradient_loss | -0.000547     |
# |    std                  | 1             |
# |    value_loss           | 3.84e+10      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 2.18e+03      |
# |    ep_rew_mean          | -2.75e+06     |
# | time/                   |               |
# |    fps                  | 811           |
# |    iterations           | 43            |
# |    time_elapsed         | 108           |
# |    total_timesteps      | 88064         |
# | train/                  |               |
# |    approx_kl            | 5.0722156e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -61           |
# |    explained_variance   | 0.00291       |
# |    learning_rate        | 0.0003        |
# |    loss                 | 1.27e+10      |
# |    n_updates            | 630           |
# |    policy_gradient_loss | -0.000646     |
# |    std                  | 1             |
# |    value_loss           | 2.85e+10      |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 2.18e+03     |
# |    ep_rew_mean          | -2.76e+06    |
# | time/                   |              |
# |    fps                  | 811          |
# |    iterations           | 44           |
# |    time_elapsed         | 110          |
# |    total_timesteps      | 90112        |
# | train/                  |              |
# |    approx_kl            | 5.598791e-06 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -61          |
# |    explained_variance   | 0.00294      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.36e+10     |
# |    n_updates            | 645          |
# |    policy_gradient_loss | -0.000725    |
# |    std                  | 1            |
# |    value_loss           | 2.68e+10     |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 2.18e+03      |
# |    ep_rew_mean          | -2.78e+06     |
# | time/                   |               |
# |    fps                  | 811           |
# |    iterations           | 45            |
# |    time_elapsed         | 113           |
# |    total_timesteps      | 92160         |
# | train/                  |               |
# |    approx_kl            | 6.3130865e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -61           |
# |    explained_variance   | 0.00259       |
# |    learning_rate        | 0.0003        |
# |    loss                 | 1.66e+10      |
# |    n_updates            | 660           |
# |    policy_gradient_loss | -0.000828     |
# |    std                  | 1             |
# |    value_loss           | 3.31e+10      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 2.18e+03      |
# |    ep_rew_mean          | -2.76e+06     |
# | time/                   |               |
# |    fps                  | 811           |
# |    iterations           | 46            |
# |    time_elapsed         | 116           |
# |    total_timesteps      | 94208         |
# | train/                  |               |
# |    approx_kl            | 5.2249525e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -61           |
# |    explained_variance   | 0.00276       |
# |    learning_rate        | 0.0003        |
# |    loss                 | 1.48e+10      |
# |    n_updates            | 675           |
# |    policy_gradient_loss | -0.000728     |
# |    std                  | 1             |
# |    value_loss           | 3.26e+10      |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 2.18e+03     |
# |    ep_rew_mean          | -2.78e+06    |
# | time/                   |              |
# |    fps                  | 810          |
# |    iterations           | 47           |
# |    time_elapsed         | 118          |
# |    total_timesteps      | 96256        |
# | train/                  |              |
# |    approx_kl            | 5.271868e-06 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -61          |
# |    explained_variance   | 0.00255      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.86e+10     |
# |    n_updates            | 690          |
# |    policy_gradient_loss | -0.00064     |
# |    std                  | 1            |
# |    value_loss           | 4.1e+10      |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 2.18e+03      |
# |    ep_rew_mean          | -2.79e+06     |
# | time/                   |               |
# |    fps                  | 810           |
# |    iterations           | 48            |
# |    time_elapsed         | 121           |
# |    total_timesteps      | 98304         |
# | train/                  |               |
# |    approx_kl            | 5.7440193e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -61           |
# |    explained_variance   | 0.00396       |
# |    learning_rate        | 0.0003        |
# |    loss                 | 5.55e+09      |
# |    n_updates            | 705           |
# |    policy_gradient_loss | -0.00073      |
# |    std                  | 1             |
# |    value_loss           | 1.78e+10      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 2.18e+03      |
# |    ep_rew_mean          | -2.79e+06     |
# | time/                   |               |
# |    fps                  | 809           |
# |    iterations           | 49            |
# |    time_elapsed         | 123           |
# |    total_timesteps      | 100352        |
# | train/                  |               |
# |    approx_kl            | 3.3191754e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -61           |
# |    explained_variance   | 0.00347       |
# |    learning_rate        | 0.0003        |
# |    loss                 | 1.25e+10      |
# |    n_updates            | 720           |
# |    policy_gradient_loss | -0.00058      |
# |    std                  | 1             |
# |    value_loss           | 2.41e+10      |
# -------------------------------------------
# PPO Training Complete.

# %%
#-------------- Evaluation -------------------
print("--- Testing PPO on Unseen Future ---")

test_set_norm=normed_data[train_end:]
test_set_raw=train_data[train_end:]

env_test=StockTradingEnv(data=test_set_norm,raw_data=test_set_raw,stock_dim=len(tickers))

obs,_=env_test.reset()
done=False
portfolio_values=[env_test.initial_balance]
buy_and_hold_values=[env_test.initial_balance]

test_initial_prices=test_set_raw[0][:,0]
initial_cash=env_test.initial_balance
bnh_holdings=(initial_cash/len(tickers))/test_initial_prices

while not done:
    action,_=model_ppo.predict(obs,deterministic=True)
    obs,_,done,_,_=env_test.step(action)
    portfolio_values.append(env_test.portfolio_value)

    if env_test.day<len(test_set_raw):
        current_prices=test_set_raw[env_test.day][:,0]
        buy_and_hold_values.append(np.sum(current_prices*bnh_holdings))

# Metrics
portfolio_values=np.array(portfolio_values)
buy_and_hold_values=np.array(buy_and_hold_values)

def calculate_metrics(values,initial_val):
    cum_ret=((values[-1]-initial_val)/initial_val)*100
    daily_rets=np.diff(values)/values[:-1]
    sharpe=(np.mean(daily_rets)/np.std(daily_rets))*np.sqrt(252) if np.std(daily_rets) > 0 else 0
    return cum_ret,sharpe

cum_ret_ppo,sharpe_ppo_test=calculate_metrics(portfolio_values,initial_cash)
cum_ret_bnh,sharpe_bnh_test=calculate_metrics(buy_and_hold_values,initial_cash)


print(f"PPO Return: {cum_ret_ppo:.2f}%")
print(f"PPO Sharpe: {sharpe_ppo_test:.4f}")
print(f"B&H Return: {cum_ret_bnh:.2f}%")

plt.figure(figsize=(12,6))
plt.plot(portfolio_values,label='PPO Agent',color='green')
plt.plot(buy_and_hold_values,label='Buy & Hold',color='black',linestyle='--')
plt.title(f'PPO vs Buy and Hold')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# --- Testing PPO on Unseen Future ---
# PPO Return: 6.16%
# PPO Sharpe: 0.4538
# B&H Return: -9.81%

# %%
import pickle
model_ppo.save(r"D:\Data Science and ML\Reinforcement Learning\Midterm Submission\nifty_data_2010_2019\ppo_model")
np.save(r"D:\Data Science and ML\Reinforcement Learning\Midterm Submission\nifty_data_2010_2019\train_data.npy",train_data)
np.save(r"D:\Data Science and ML\Reinforcement Learning\Midterm Submission\nifty_data_2010_2019\normed_data.npy",normed_data)

# %%
full_processed_data=np.load(r"D:\Data Science and ML\Reinforcement Learning\Midterm Submission\processed_data.npy")


train_end_idx=int(len(full_processed_data)*0.7)


eval_raw_data=full_processed_data[train_end_idx:]
eval_norm_data=full_processed_data[train_end_idx:]


env_test=StockTradingEnv(
    data=eval_norm_data,
    raw_data=eval_raw_data,
    stock_dim=len(tickers)
)

model=PPO.load(r"D:\Data Science and ML\Reinforcement Learning\Midterm Submission\ppo_nifty_model_v1.zip",env=env_test)

obs,_=env_test.reset()
done=False

portfolio_values=[env_test.initial_balance]
buy_and_hold_values=[env_test.initial_balance]

test_initial_prices=eval_raw_data[0][:,0]
initial_cash=env_test.initial_balance
bnh_holdings=(initial_cash/len(tickers))/test_initial_prices

print("--- Running Deterministic Evaluation ---")

while not done:
    action,_=model.predict(obs,deterministic=True)

    obs,_,done,_,_=env_test.step(action)

    portfolio_values.append(env_test.portfolio_value)

    if env_test.day<len(eval_raw_data):
        current_prices=eval_raw_data[env_test.day][:,0]
        buy_and_hold_values.append(np.sum(current_prices*bnh_holdings))

portfolio_values=np.array(portfolio_values)
buy_and_hold_values=np.array(buy_and_hold_values)

def calculate_metrics(values,initial_val):
    cum_ret=((values[-1] - initial_val)/initial_val)*100
    daily_rets=np.diff(values)/(values[:-1])
    sharpe=(np.mean(daily_rets)/(np.std(daily_rets)+1e-10))*np.sqrt(252)
    return cum_ret,sharpe

cum_ret_ppo,sharpe_ppo=calculate_metrics(portfolio_values,initial_cash)
cum_ret_bnh,sharpe_bnh=calculate_metrics(buy_and_hold_values,initial_cash)

print(f"\n" + "="*30)
print(f"{'Metric':<15} | {'PPO Agent':<12} | {'Buy & Hold':<12}")
print("-"*45)
print(f"{'Total Return':<15} | {cum_ret_ppo:>10.2f}% | {cum_ret_bnh:>10.2f}%")
print(f"{'Sharpe Ratio':<15} | {sharpe_ppo:>10.4f} | {sharpe_bnh:>10.4f}")
print("="*30)

plt.figure(figsize=(12,6))
plt.plot(portfolio_values,label='PPO Agent (Strictly Deterministic)',color='green',linewidth=2)
plt.plot(buy_and_hold_values,label='Buy & Hold Benchmark',color='black',linestyle='--',alpha=0.7)
plt.title('Final Evaluation: PPO vs Benchmark')
plt.xlabel('Trading Days')
plt.ylabel('Portfolio Value ($)')
plt.legend()
plt.grid(True,alpha=0.3)
plt.show()
# Out:
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# --- Running Deterministic Evaluation ---
#
# ==============================
# Metric          | PPO Agent    | Buy & Hold
# ---------------------------------------------
# Total Return    |      40.27% |      12.59%
# Sharpe Ratio    |     0.8959 |     0.3339
# ==============================
